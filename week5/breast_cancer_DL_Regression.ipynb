# %% [markdown]
# <a href="https://colab.research.google.com/github/gocleanwater/AI-class/blob/main/week5/breast_cancer_DL_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
path='/content/drive/MyDrive/Colab Notebooks/AI-class/week2/breast_cancer.csv'
df = pd.read_csv(path)
df
# Out:
#      Unnamed: 0  mean radius  mean texture  mean perimeter  mean area  \
# 0             0        17.99         10.38          122.80     1001.0
# 1             1        20.57         17.77          132.90     1326.0
# 2             2        19.69         21.25          130.00     1203.0
# 3             3        11.42         20.38           77.58      386.1
# 4             4        20.29         14.34          135.10     1297.0
# ..          ...          ...           ...             ...        ...
# 564         564        21.56         22.39          142.00     1479.0
# 565         565        20.13         28.25          131.20     1261.0
# 566         566        16.60         28.08          108.30      858.1
# 567         567        20.60         29.33          140.10     1265.0
# 568         568         7.76         24.54           47.92      181.0
#
#      mean smoothness  mean compactness  mean concavity  mean concave points  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      mean symmetry  ...  worst texture  worst perimeter  worst area  \
# 0           0.2419  ...          17.33           184.60      2019.0
# 1           0.1812  ...          23.41           158.80      1956.0
# 2           0.2069  ...          25.53           152.50      1709.0
# 3           0.2597  ...          26.50            98.87       567.7
# 4           0.1809  ...          16.67           152.20      1575.0
# ..             ...  ...            ...              ...         ...
# 564         0.1726  ...          26.40           166.10      2027.0
# 565         0.1752  ...          38.25           155.00      1731.0
# 566         0.1590  ...          34.12           126.70      1124.0
# 567         0.2397  ...          39.42           184.60      1821.0
# 568         0.1587  ...          30.37            59.16       268.6
#
#      worst smoothness  worst compactness  worst concavity  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      worst concave points  worst symmetry  worst fractal dimension  label
# 0                  0.2654          0.4601                  0.11890      0
# 1                  0.1860          0.2750                  0.08902      0
# 2                  0.2430          0.3613                  0.08758      0
# 3                  0.2575          0.6638                  0.17300      0
# 4                  0.1625          0.2364                  0.07678      0
# ..                    ...             ...                      ...    ...
# 564                0.2216          0.2060                  0.07115      0
# 565                0.1628          0.2572                  0.06637      0
# 566                0.1418          0.2218                  0.07820      0
# 567                0.2650          0.4087                  0.12400      0
# 568                0.0000          0.2871                  0.07039      1
#
# [569 rows x 32 columns]

# %%
df = df.drop('label', axis=1)
df.head()
# Out:
#    Unnamed: 0  mean radius  mean texture  mean perimeter  mean area  \
# 0           0        17.99         10.38          122.80     1001.0
# 1           1        20.57         17.77          132.90     1326.0
# 2           2        19.69         21.25          130.00     1203.0
# 3           3        11.42         20.38           77.58      386.1
# 4           4        20.29         14.34          135.10     1297.0
#
#    mean smoothness  mean compactness  mean concavity  mean concave points  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    mean symmetry  ...  worst radius  worst texture  worst perimeter  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
y = df['mean radius']
print(y.describe())
print(y.hist())
# Out:
# count    569.000000
# mean      14.127292
# std        3.524049
# min        6.981000
# 25%       11.700000
# 50%       13.370000
# 75%       15.780000
# max       28.110000
# Name: mean radius, dtype: float64
# Axes(0.125,0.11;0.775x0.77)

# %%
X = df.drop('mean radius', axis=1)
X.head()
# Out:
#    Unnamed: 0  mean texture  mean perimeter  mean area  mean smoothness  \
# 0           0         10.38          122.80     1001.0          0.11840
# 1           1         17.77          132.90     1326.0          0.08474
# 2           2         21.25          130.00     1203.0          0.10960
# 3           3         20.38           77.58      386.1          0.14250
# 4           4         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %% [markdown]
# ## 1. 데이터 형태 변환 + 데이터 분할 + Scaling

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X = X.values
y = y.values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (455, 30) (114, 30)
# (455,) (114,)

# %% [markdown]
# ## 2. 딥러닝 모델 생성, 학습, 평가

# %%
import tensorflow as tf

layers = tf.keras.layers
models = tf.keras.models

model = models.Sequential([
    layers.Input(shape=(X_train.shape[1],)), # 입력층 현재 30개의 열을 입력
    layers.Dense(64, activation='relu'), # 은닉층
    layers.Dropout(0.3), # Drop out
    layers.Dense(32, activation='relu'), #은닉층
    layers.Dense(1) #출력 1 Regression이므로 activation이 존재하지 않음
])

model.compile(
    optimizer='adam',
    loss='mse', # Regression이므로 loss function이 mse
    metrics=['mae', 'mse'] # Regression이므로 metrics가 mae(평균 절대 오차), mse이다.
)

history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=50,
    batch_size=16,
    verbose=1
)
# Out:
# Epoch 1/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 183.8143 - mae: 13.1886 - mse: 183.8143 - val_loss: 167.7622 - val_mae: 12.6534 - val_mse: 167.7622
# Epoch 2/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 129.5280 - mae: 11.0737 - mse: 129.5280 - val_loss: 104.7159 - val_mae: 9.8564 - val_mse: 104.7159
# Epoch 3/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 69.6156 - mae: 7.7472 - mse: 69.6156 - val_loss: 54.0604 - val_mae: 6.5453 - val_mse: 54.0604
# Epoch 4/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 34.8956 - mae: 5.0432 - mse: 34.8956 - val_loss: 40.8077 - val_mae: 5.2704 - val_mse: 40.8077
# Epoch 5/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 26.8164 - mae: 4.2198 - mse: 26.8164 - val_loss: 34.6899 - val_mae: 4.8845 - val_mse: 34.6899
# Epoch 6/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 24.8122 - mae: 4.0981 - mse: 24.8122 - val_loss: 30.5892 - val_mae: 4.6061 - val_mse: 30.5892
# Epoch 7/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.6896 - mae: 3.6039 - mse: 19.6896 - val_loss: 26.9950 - val_mae: 4.2395 - val_mse: 26.9950
# Epoch 8/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18
# Epoch 32/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.1865 - mae: 1.8188 - mse: 5.1865 - val_loss: 4.6484 - val_mae: 1.5908 - val_mse: 4.6484
# Epoch 33/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6040 - mae: 1.9491 - mse: 5.6040 - val_loss: 4.2128 - val_mae: 1.5705 - val_mse: 4.2128
# Epoch 34/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.3954 - mae: 1.8485 - mse: 5.3954 - val_loss: 4.7589 - val_mae: 1.5775 - val_mse: 4.7589
# Epoch 35/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2720 - mae: 1.7984 - mse: 5.2720 - val_loss: 3.6412 - val_mae: 1.4412 - val_mse: 3.6412
# Epoch 36/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6384 - mae: 1.7163 - mse: 4.6384 - val_loss: 4.4242 - val_mae: 1.5293 - val_mse: 4.4242
# Epoch 37/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1768 - mae: 1.6285 - mse: 4.1768 - val_loss: 3.6137 - val_mae: 1.4042 - val_mse: 3.6137
# Epoch 38/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7392 - mae: 1.6797 - mse: 4.7392 - val_loss: 3.1198 - val_mae: 1.3824 - val_mse: 3.1198
# Epoch 39/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.3651 - mae: 1.6438 - mse: 4.3651 - val_loss: 3.2787 - val_mae: 1.3788 - val_mse: 3.2787
# Epoch 40/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6807 - mae: 1.5396 - mse: 3.6807 - val_loss: 3.4911 - val_mae: 1.3801 - val_mse: 3.4911
# Epoch 41/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0539 - mae: 1.6136 - mse: 4.0539 - val_loss: 3.5675 - val_mae: 1.3670 - val_mse: 3.5675
# Epoch 42/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.1010 - mae: 1.7386 - mse: 5.1010 - val_loss: 2.9197 - val_mae: 1.3225 - val_mse: 2.9197
# Epoch 43/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0829 - mae: 1.5947 - mse: 4.0829 - val_loss: 3.1438 - val_mae: 1.2907 - val_mse: 3.1438
# Epoch 44/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0050 - mae: 1.5985 - mse: 4.0050 - val_loss: 3.4444 - val_mae: 1.3329 - val_mse: 3.4444
# Epoch 45/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9392 - mae: 1.5268 - mse: 3.9392 - val_loss: 2.9160 - val_mae: 1.3045 - val_mse: 2.9160
# Epoch 46/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2808 - mae: 1.5971 - mse: 4.2808 - val_loss: 3.2055 - val_mae: 1.2884 - val_mse: 3.2055
# Epoch 47/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.8527 - mae: 1.5357 - mse: 3.8527 - val_loss: 3.3940 - val_mae: 1.3709 - val_mse: 3.3940
# Epoch 48/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4209 - mae: 1.4611 - mse: 3.4209 - val_loss: 2.7771 - val_mae: 1.2245 - val_mse: 2.7771
# Epoch 49/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.7159 - mae: 1.4585 - mse: 3.7159 - val_loss: 2.5204 - val_mae: 1.2097 - val_mse: 2.5204
# Epoch 50/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1271 - mae: 1.3784 - mse: 3.1271 - val_loss: 2.8173 - val_mae: 1.2222 - val_mse: 2.8173

# %% [markdown]
# ## 3. 예측 및 평가

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

y_pred = model.predict(X_test)

y_pred = y_pred.flatten()
y_test = y_test.flatten()

mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("MSE :", mse)
print("RMSE:", rmse) # Root MSE
print("MAE :", mae)
print("R2  :", r2) # 결정계수(coefficient of determination)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# MSE : 2.219440743768494
# RMSE: 1.4897787566509646
# MAE : 1.0618038068737898
# R2  : 0.8165167658876199

# %% [markdown]
# ## 4. 학습 과정 시각화

# %%
import matplotlib.pyplot as plt

loss = history.history['loss']
val_loss = history.history['val_loss']
mae = history.history['mae']
val_mae = history.history['val_mae']

epochs = range(1, len(loss) + 1)

# %% [markdown]
# ## 손실 그래프

# %%
plt.figure(figsize=(8, 5))
plt.plot(epochs, loss, label='Training loss')
plt.plot(epochs, val_loss, label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.show()

# %% [markdown]
# ## MAE 그래프

# %%
plt.figure(figsize=(8, 5))
plt.plot(epochs, mae, label='Training MAE')
plt.plot(epochs, val_mae, label='Validation MAE')
plt.title('Training and validation MAE')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.show()
